# %% [markdown]
# # Baltimore Arrests Before and After Freddie Gray

# %% [markdown]
# Notes

# %%
import sys
import pandas as pd
import numpy
from datetime import datetime
import time_parser
import import_funcs
#reload(import_funcs)
BPD_arrests = import_funcs.import_BPDarrests()

# %%
# Out:
#                        Arrest  Age Sex Race      ArrestLocation  \
# timestamp
# 2015-05-30 03:30:00  15082162   16   M    B    5700 RADECKE AVE
# 2015-05-30 07:50:00  15082181   38   M    B    400 S PULASKI ST
# 2015-05-30 07:50:00  15082189   24   F    B    400 S PULASKI ST
# 2015-05-30 02:39:00  15082153   42   M    B    800 WHITELOCK ST
# 2015-05-30 18:00:00  15082229   26   M    B         3500 3RD ST
# 2015-05-30 06:00:00  15082172   31   M    B  2800 RIDGEWOOD AVE
# 2015-05-30 05:02:00  15082167   23   M    W   2600 E FAYETTE ST
# 2015-05-30 20:00:00  15082317   21   M    B  1900 FREDERICK AVE
# 2015-05-30 00:10:00       NaN   34   M    B   1400 E PRESTON ST
# 2015-05-30 19:50:00  15082239   50   M    B  1100 WINCHESTER ST
# 2015-05-30 19:50:00  15082262   50   M    B                 NaN
# 2015-05-30 19:50:00  15082261   50   M    B                 NaN
# 2015-05-30 03:15:00  15082156   46   M    W                 NaN
# 2015-05-30 03:15:00  15082155   46   M    W                 NaN
# 2015-05-30 01:20:00  15082118   67   M    B                 NaN
# 2015-05-30 02:20:00       NaN   39   M    B                 NaN
# 2015-05-30 02:00:00  15082142   40   M    B                 NaN
# 2015-05-30 03:30:00  15082152   28   M    B                 NaN
# 2015-05-30 00:30:00  15082158   24   F    B                 NaN
# 2015-05-30 04:30:00  15082161   32   M    B                 NaN
# 2015-05-30 06:00:00  15082177   46   F    B                 NaN
# 2015-05-30 06:05:00  15082175   21   F    B                 NaN
# 2015-05-30 08:15:00       NaN   43   M    W                 NaN
# 2015-05-30 09:00:00  15082188   27   M    B                 NaN
# 2015-05-30 03:30:00  15082165   28   M    B                 NaN
#
#                                   IncidentOffense            IncidentLocation  \
# timestamp
# 2015-05-30 03:30:00               Unknown Offense  Moores Run Dr & Radecke Av
# 2015-05-30 07:50:00               Unknown Offense            400 S Pulaski St
# 2015-05-30 07:50:00               Unknown Offense            400 S Pulaski St
# 2015-05-30 02:39:00             4E-Common Assault            800 Whitelock St
# 2015-05-30 18:00:00               Unknown Offense                 3500 3Rd St
# 2015-05-30 06:00:00               Unknown Offense          2800 Ridgewood Ave
# 2015-05-30 05:02:00             4E-Common Assault              100 S East Ave
# 2015-05-30 20:00:00               Unknown Offense          1900 Frederick Ave
# 2015-05-30 00:10:00               Unknown Offense                         NaN
# 2015-05-30 19:50:00  118-Burglary - Fourth Degree          1100 Winchester St
# 2015-05-30 19:50:00       6C-Larceny- Shoplifting        2000 Gwynns Falls Pw
# 2015-05-30 19:50:00       87O-Narcotics (Outside)             1600 W North Av
# 2015-05-30 03:15:00                      79-Other             1300 W Pratt St
# 2015-05-30 03:15:00                  87-Narcotics             1200 W Pratt St
# 2015-05-30 01:20:00               Unknown Offense                         NaN
# 2015-05-30 02:20:00               Unknown Offense                         NaN
# 2015-05-30 02:00:00               Unknown Offense                         NaN
# 2015-05-30 03:30:00               Unknown Offense                         NaN
# 2015-05-30 00:30:00               Unknown Offense                         NaN
# 2015-05-30 04:30:00               Unknown Offense                         NaN
# 2015-05-30 06:00:00               Unknown Offense                         NaN
# 2015-05-30 06:05:00               Unknown Offense                         NaN
# 2015-05-30 08:15:00               Unknown Offense                         NaN
# 2015-05-30 09:00:00               Unknown Offense                         NaN
# 2015-05-30 03:30:00               Unknown Offense                         NaN
#
#                      Charge  \
# timestamp
# 2015-05-30 03:30:00  1 5212
# 2015-05-30 07:50:00  1 1130
# 2015-05-30 07:50:00  1 1130
# 2015-05-30 02:39:00  1 1415
# 2015-05-30 18:00:00  1 1415
# 2015-05-30 06:00:00  1 0622
# 2015-05-30 05:02:00  1 1415
# 2015-05-30 20:00:00  1 0493
# 2015-05-30 00:10:00     NaN
# 2015-05-30 19:50:00  1 1130
# 2015-05-30 19:50:00  1 0077
# 2015-05-30 19:50:00  1 0077
# 2015-05-30 03:15:00  1 0077
# 2015-05-30 03:15:00  1 0088
# 2015-05-30 01:20:00  1 0077
# 2015-05-30 02:20:00     NaN
# 2015-05-30 02:00:00  1 0990
# 2015-05-30 03:30:00  1 1415
# 2015-05-30 00:30:00  2 0700
# 2015-05-30 04:30:00  1 1415
# 2015-05-30 06:00:00  1 1415
# 2015-05-30 06:05:00  1 1415
# 2015-05-30 08:15:00     NaN
# 2015-05-30 09:00:00  2A3030
# 2015-05-30 03:30:00  999999
#
#                                                      ChargeDescription  \
# timestamp
# 2015-05-30 03:30:00             Handgun On Person || Handgun Violation
# 2015-05-30 07:50:00         Burglary-4Th Degree-Store || Child Neglect
# 2015-05-30 07:50:00         Burglary-4Th Degree-Store || Child Neglect
# 2015-05-30 02:39:00                 Asslt-Sec Degree || Common Assault
# 2015-05-30 18:00:00                        Asslt-Sec Degree || Assault
# 2015-05-30 06:00:00      Theft: $1,000 To Under $10,000 || Stolen Auto
# 2015-05-30 05:02:00                 Asslt-Sec Degree || Common Assault
# 2015-05-30 20:00:00                     Firearm/Drug Traf Crime || Hgv
# 2015-05-30 00:10:00                                     Unknown Charge
# 2015-05-30 19:50:00  Burglary-4Th Degree-Store || Breaking And Ente...
# 2015-05-30 19:50:00             Failure To Appear || Failure To Appear
# 2015-05-30 19:50:00             Failure To Appear || Failure To Appear
# 2015-05-30 03:15:00             Failure To Appear || Failure To Appear
# 2015-05-30 03:15:00   Violation Of Probation || Violation Of Probation
# 2015-05-30 01:20:00             Failure To Appear || Failure To Appear
# 2015-05-30 02:20:00                                     Unknown Charge
# 2015-05-30 02:00:00                                                NaN
# 2015-05-30 03:30:00             Asslt-Sec Degree || Assault-Sec Degree
# 2015-05-30 00:30:00                                 Robbery || Robbery
# 2015-05-30 04:30:00             Asslt-Sec Degree || Assault-Sec Degree
# 2015-05-30 06:00:00             Asslt-Sec Degree || Assault-Sec Degree
# 2015-05-30 06:05:00             Asslt-Sec Degree || Assault-Sec Degree
# 2015-05-30 08:15:00                                     Unknown Charge
# 2015-05-30 09:00:00  Att-Burglary-Fourth Degree || Att-Burglary- 4T...
# 2015-05-30 03:30:00   Violation Of Probation || Violation Of Probation
#
#                          District  Post                 Neighborhood  \
# timestamp
# 2015-05-30 03:30:00  Northeastern   435                    FRANKFORD
# 2015-05-30 07:50:00  Southwestern   835             CARROLLTON RIDGE
# 2015-05-30 07:50:00  Southwestern   835             CARROLLTON RIDGE
# 2015-05-30 02:39:00       Central   134               RESERVOIR HILL
# 2015-05-30 18:00:00      Southern   912                     BROOKLYN
# 2015-05-30 06:00:00  Northwestern   613                 LUCILLE PARK
# 2015-05-30 05:02:00  Southeastern   222  PATTERSON PARK NEIGHBORHOOD
# 2015-05-30 20:00:00  Southwestern   836                   BOYD-BOOTH
# 2015-05-30 00:10:00       Eastern   322                       OLIVER
# 2015-05-30 19:50:00       Western   715          SANDTOWN-WINCHESTER
# 2015-05-30 19:50:00           NaN   NaN                          NaN
# 2015-05-30 19:50:00           NaN   NaN                          NaN
# 2015-05-30 03:15:00           NaN   NaN                          NaN
# 2015-05-30 03:15:00           NaN   NaN                          NaN
# 2015-05-30 01:20:00           NaN   NaN                          NaN
# 2015-05-30 02:20:00           NaN   NaN                          NaN
# 2015-05-30 02:00:00           NaN   NaN                          NaN
# 2015-05-30 03:30:00           NaN   NaN                          NaN
# 2015-05-30 00:30:00           NaN   NaN                          NaN
# 2015-05-30 04:30:00           NaN   NaN                          NaN
# 2015-05-30 06:00:00           NaN   NaN                          NaN
# 2015-05-30 06:05:00           NaN   NaN                          NaN
# 2015-05-30 08:15:00           NaN   NaN                          NaN
# 2015-05-30 09:00:00           NaN   NaN                          NaN
# 2015-05-30 03:30:00           NaN   NaN                          NaN
#
#                                           Location 1  lat  long
# timestamp
# 2015-05-30 03:30:00  (39.3301171565, -76.5355466079)  NaN   NaN
# 2015-05-30 07:50:00  (39.2815794366, -76.6494008179)  NaN   NaN
# 2015-05-30 07:50:00  (39.2815794366, -76.6494008179)  NaN   NaN
# 2015-05-30 02:39:00  (39.3143988640, -76.6324530538)  NaN   NaN
# 2015-05-30 18:00:00  (39.2393134555, -76.6062030549)  NaN   NaN
# 2015-05-30 06:00:00  (39.3395755912, -76.6698783582)  NaN   NaN
# 2015-05-30 05:02:00  (39.2945104497, -76.5798474975)  NaN   NaN
# 2015-05-30 20:00:00  (39.2867873093, -76.6469923030)  NaN   NaN
# 2015-05-30 00:10:00  (39.3051820542, -76.5994664631)  NaN   NaN
# 2015-05-30 19:50:00  (39.3024740840, -76.6369742688)  NaN   NaN
# 2015-05-30 19:50:00                              NaN  NaN   NaN
# 2015-05-30 19:50:00                              NaN  NaN   NaN
# 2015-05-30 03:15:00                              NaN  NaN   NaN
# 2015-05-30 03:15:00                              NaN  NaN   NaN
# 2015-05-30 01:20:00                              NaN  NaN   NaN
# 2015-05-30 02:20:00                              NaN  NaN   NaN
# 2015-05-30 02:00:00                              NaN  NaN   NaN
# 2015-05-30 03:30:00                              NaN  NaN   NaN
# 2015-05-30 00:30:00                              NaN  NaN   NaN
# 2015-05-30 04:30:00                              NaN  NaN   NaN
# 2015-05-30 06:00:00                              NaN  NaN   NaN
# 2015-05-30 06:05:00                              NaN  NaN   NaN
# 2015-05-30 08:15:00                              NaN  NaN   NaN
# 2015-05-30 09:00:00                              NaN  NaN   NaN
# 2015-05-30 03:30:00                              NaN  NaN   NaN

# %%
figs = plt.figure(figsize(16,4))
BPD_arrests['Arrest'].resample('m',how='count').plot(kind='bar')

# %%
figs = plt.figure(figsize=[12,4])
ax1 = plt.subplot(1,1,1)

anncolor = '#aaaaaa'

plot_span = BPD_arrests['Arrest'].ix['05-jan-2015':'may-2015'].resample('w',how='count',label='left')
plot_span.plot(kind='bar', grid='off')

#ax1.text(0,700,'Weekly Arrests in Baltimore',fontsize=20)
# turn off square border around plot
ax1.spines["top"].set_visible(False)  
ax1.spines["bottom"].set_visible(False)  
ax1.spines["right"].set_visible(False)  
ax1.spines["left"].set_visible(False)

# turn off ticks
ax1.tick_params(axis="both", which="both", bottom="off", top="off",
               labelbottom="on", left="off", right="off", labelleft="on",labelsize=14)

ax1.set_xticklabels([dt.strftime('%b %d') for dt in plot_span.index.to_pydatetime()], 
                    rotation=90, 
                    ha='center',
                    fontsize=14,
                    color=anncolor)

ax1.tick_params(axis='y', colors=anncolor)

plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.25)
xlabel('')
plt.show()

figs.savefig('plots/baltimore_2015_weekly_arrest_count_thru_may.png', bbox_tight='inches', pad=.2)

# %%
fig = plt.figure(figsize=[18,4])

anncolor = '#aaaaaa'

ax1 = plt.subplot(1,1,1)

plot_span = BPD_arrests['Arrest'].ix['1-apr-2015':'may-2015'].resample('d',how='count')

plot1 = plot(plot_span.index,pd.rolling_mean(plot_span,5),'r',linewidth=3)
plot2 = bar(plot_span.index,plot_span, color=anncolor, align='center')

import matplotlib.dates as dates
ax1.set_xticks(plot_span.index)
ax1.set_xticklabels([dt.strftime('%d') for dt in plot_span.index.to_pydatetime()], 
                    rotation=90, 
                    fontsize=10,
                    ha='center')


date_protests = '25-apr-2015'
ax1.annotate('Saturday Protests',xy=(pd.to_datetime(date_protests),plot_span.ix['25-apr-15']+2),
             xytext=(pd.to_datetime(date_protests),plot_span.ix['25-apr-15']+50),
             horizontalalignment='right',
             fontsize=16,
             color=anncolor,
             arrowprops=dict(color=anncolor,
                             width=0.1,
                             headwidth=0.0,
                             shrink=0.05))

date_riots = '27-apr-2015'
ax1.annotate('Monday Riots',xy=(pd.to_datetime(date_riots),plot_span.ix['27-apr-15']+2),
             xytext=(pd.to_datetime(date_riots),plot_span.ix['27-apr-15']+50),
             horizontalalignment='right',
             fontsize=16,
             color=anncolor,
             arrowprops=dict(color=anncolor,
                             width=0.1,
                             headwidth=0.0,
                             shrink=0.05))

date_charged = '01-may-2015'
ax1.annotate('Officers Charged',xy=(pd.to_datetime(date_charged),plot_span.ix[date_charged]+2),
             xytext=(pd.to_datetime(date_charged),plot_span.ix[date_charged]+50),
             horizontalalignment='left',
             fontsize=16,
             color=anncolor,
             arrowprops=dict(color=anncolor,
                             width=0.1,
                             headwidth=0.0,
                             shrink=0.05))


#ax1.text(0,800,'Daily Arrests in Baltimore',fontsize=20)
# turn off square border around plot
ax1.spines["top"].set_visible(False)  
ax1.spines["bottom"].set_visible(False)  
ax1.spines["right"].set_visible(False)  
ax1.spines["left"].set_visible(False)

# turn off ticks
ax1.tick_params(axis="both", which="both", bottom="off", top="off",
               labelbottom="on", left="off", right="off", labelleft="on",labelsize=14)
grid('off')

legend(['5-day Moving Average'],framealpha=0)

ax1.tick_params(axis='x', colors=anncolor)
ax1.tick_params(axis='y', colors=anncolor)
xlabel('')
ylabel('Arrests',color=anncolor,fontsize=16)

plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.2)

ax1.text(pd.to_datetime('1-apr-2015'),-30,'April',fontsize=14,color=anncolor,ha='center')
ax1.text(pd.to_datetime('1-may-2015'),-30,'May',fontsize=14,color=anncolor,ha='center')

plt.show()

fig.savefig('plots/baltimore_daily_arrest_count_around_FG.png', bbox_tight='inches')

# %%
# Out:
# <bound method XAxis.set_minor_locator of <matplotlib.axis.XAxis object at 0x122754e10>>

# %% [markdown]
# # Preliminary work for location-based shifts in policing

# %%
def parse_lat_long(df):
    
    temp = df['Location 1'].str.strip('(').str.strip(')')
    temp = temp.apply(lambda x: str(x).split(','))
    
    df['lat'] = pd.Series()
    df['long'] = pd.Series()
    
    for i, j in enumerate(temp):
        if size(temp[i]) == 0:
            df['lat'].ix[i] = 'NaN'
        else:
            df['lat'].ix[i] = temp[i].iloc[0]            
        
#    for k, l in enumerate(temp):
#        if size(temp[k]) == 0:
#            df['long'].ix[k] = 'NaN'
#        else:
#            df['long'].ix[k] = temp[k].iloc[1]
            
    return df

# %%
#march_arrests = parse_lat_long(BPD_arrests.ix['march-2015'])
#april_arrests = parse_lat_long(BPD_arrests.ix['apr-2015'])
may_arrests = parse_lat_long(BPD_arrests.ix['may-2015'])

#BPD_arrests.to_csv('BPD_arrests_2015-06-11_lat_long.csv')

# %%
march_arrests['lat'][march_arrests['lat']!='nan'].count() / float(march_arrests['lat'].count())
# Out:
# 0.56013240161824196

# %%
march_arrests['lat'].count()
# Out:
# 2719
