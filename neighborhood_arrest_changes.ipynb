# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_excel('output/neighborhood_arrests_shapefile_131415_floats_pop200.xlsx')

data.head()
# Out:
#    age18_24  vacant  married  femalehh  blk_afam  asian  occ_own  vac_other  \
# 0       118      75      105        42       213     33      248         22
# 1       317     175      253       510      3497      6      818         56
# 2       116      48      194        88       537     12      356         25
# 3       231     233      215       294      2496      9      485        145
# 4       272      84      431       331       108     14      981         41
#
#    malehh  other_race     ...      arr13  arr14  arr15  PcCng1314  PcCng1415  \
# 0      12           4     ...         23     25     10   8.695652 -60.000000
# 1     111           5     ...        128     97     47 -24.218750 -51.546392
# 2      23          10     ...         46     24     42 -47.826087  75.000000
# 3      76          10     ...        354    193    120 -45.480226 -37.823834
# 4     115         413     ...         86     36     17 -58.139535 -52.777778
#
# ...

# %%
fig = plt.figure(figsize=[10,4])
ax1 = plt.subplot(1,1,1)
linewidth = 1.5

data['PcCng1415'].hist(bins=20)

# turn off square border around plot
ax1.spines["top"].set_visible(False)  
ax1.spines["bottom"].set_visible(False)  
ax1.spines["right"].set_visible(False)  
ax1.spines["left"].set_visible(False)

# turn off ticks
ax1.tick_params(axis="both", which="both", bottom="off", top="off",
               labelbottom="on", left="off", right="off", labelleft="on",labelsize=14)
grid('off')

text(350,80,'Percent Change in Total Arrests by Neighborhood\nfrom 2014 to 2015', fontsize=14, ha='right')
text(350,10,'thetrainingset.com', fontsize=10, ha='right')

xlabel('Percent Change', fontsize=14)
ylabel('Number of Baltimore Neighborhoods', fontsize=14)

fig.savefig('plots/Histogram - Percent Change in Arrests by Nhood.png', bbox_tight='inches')

# %%
fig = plt.figure(figsize=[10,4])
ax1 = plt.subplot(1,1,1)
linewidth = 1.5

data['RtChg1415'].hist(bins=20)

# turn off square border around plot
ax1.spines["top"].set_visible(False)  
ax1.spines["bottom"].set_visible(False)  
ax1.spines["right"].set_visible(False)  
ax1.spines["left"].set_visible(False)

# turn off ticks
ax1.tick_params(axis="both", which="both", bottom="off", top="off",
               labelbottom="on", left="off", right="off", labelleft="on",labelsize=14)
grid('off')

text(-190,90,'Change in Arrest Rate per 1,000 Population\nby Neighborhood, from 2014 to 2015', fontsize=14, ha='left')
text(-190,10,'thetrainingset.com', fontsize=10, ha='left')

xlabel('Change in Arrest Rate per 1,000 Population', fontsize=14)
ylabel('Number of Baltimore Neighborhoods', fontsize=14)

fig.savefig('plots/Histogram - Change in Arrest Rate by Nhood.png', bbox_tight='inches')
